# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
def get_weights(n_features, n_labels):
    return tf.Variable(tf.truncated_normal((n_features, n_labels)))

# %%
def get_biases(n_labels):
    return tf.Variable(tf.zeros(n_labels))

# %%
def linear(input, w, b):
    
    return tf.add(tf.matmul(input, w), b)

# %%
def mnist_features_labels(n_labels):  
    mnist_features = []
    mnist_labels = []  
    mnist = input_data.read_data_sets('/datasets/ud730/mnist', one_hot=True)
    
        # In order to make quizzes run faster, we're only looking at 10000 images
    for mnist_feature, mnist_label in zip(*mnist.train.next_batch(10000)):

        # Add features and labels if it's for the first <n>th labels
        if mnist_label[:n_labels].any():
            mnist_features.append(mnist_feature)
            mnist_labels.append(mnist_label[:n_labels])

    return mnist_features, mnist_labels

# %%
# Number of features (28*28 image is 784 features)
n_features = 784
# Number of labels
n_labels = 3

# %%
features = tf.placeholder(tf.float32)
labels = tf.placeholder(tf.float32)

# Weights and Biases
w = get_weights(n_features, n_labels)
b = get_biases(n_labels)

# Linear Function xW + b
logits = linear(features, w, b)

# Training data
train_features, train_labels = mnist_features_labels(n_labels)
# Out:
# Extracting /datasets/ud730/mnist\train-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\train-labels-idx1-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-labels-idx1-ubyte.gz

# %%
with tf.Session() as session:
    session.run(tf.global_variables_initializer())

    # Softmax
    prediction = tf.nn.softmax(logits)

    # Cross entropy
    # This quantifies how far off the predictions were.
    # You'll learn more about this in future lessons.
    cross_entropy = -tf.reduce_sum(labels * tf.log(prediction), reduction_indices=1)

    # Training loss
    # You'll learn more about this in future lessons.
    loss = tf.reduce_mean(cross_entropy)

    # Rate at which the weights are changed
    # You'll learn more about this in future lessons.
    learning_rate = 0.08

    # Gradient Descent
    # This is the method used to train the model
    # You'll learn more about this in future lessons.
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

    
    # Run optimizer and get loss
    _, l = session.run(
        [optimizer, loss],
        feed_dict={features: train_features, labels: train_labels})

# Print loss
print('Loss: {}'.format(l))
# Out:
# Loss: 6.701938629150391

# %%
import math
def batches(batch_size, features, labels):
    """
    Create batches of features and labels
    :param batch_size: The batch size
    :param features: List of features
    :param labels: List of labels
    :return: Batches of (Features, Labels)
    """
    assert len(features) == len(labels)
    outout_batches = []
    
    sample_size = len(features)
    for start_i in range(0, sample_size, batch_size,):
        end_i = start_i + batch_size
        batch = [features[start_i:end_i], labels[start_i:end_i]]
        outout_batches.append(batch)
        
    return outout_batches

# %% [markdown]
# # Creating Batches

# %%
def print_epoch_stats(epoch_i, sess, last_features, last_labels):
    """
    Print cost and validation accuracy of an epoch
    """
    current_cost = sess.run(
        cost,
        feed_dict={features: last_features, labels: last_labels})
    valid_accuracy = sess.run(
        accuracy,
        feed_dict={features: valid_features, labels: valid_labels})
    print('Epoch: {:<4} - Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        epoch_i,
        current_cost,
        valid_accuracy))

n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)

# Import MNIST data
mnist = input_data.read_data_sets('/datasets/ud730/mnist', one_hot=True)

# The features are already scaled and the data is shuffled
train_features = mnist.train.images
valid_features = mnist.validation.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
valid_labels = mnist.validation.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

# Features and Labels
features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

# Weights & bias
weights = tf.Variable(tf.random_normal([n_input, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# Logits - xW + b
logits = tf.add(tf.matmul(features, weights), bias)

# Define loss and optimizer
learning_rate = tf.placeholder(tf.float32)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Calculate accuracy
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

init = tf.global_variables_initializer()

batch_size = 128
epochs = 200
learn_rate = 0.1

train_batches = batches(batch_size, train_features, train_labels)

with tf.Session() as sess:
    sess.run(init)

    # Training cycle
    for epoch_i in range(epochs):

        # Loop over all batches
        for batch_features, batch_labels in train_batches:
            train_feed_dict = {
                features: batch_features,
                labels: batch_labels,
                learning_rate: learn_rate}
            sess.run(optimizer, feed_dict=train_feed_dict)

        # Print cost and validation accuracy of an epoch
        print_epoch_stats(epoch_i, sess, batch_features, batch_labels)

    # Calculate accuracy for test dataset
    test_accuracy = sess.run(
        accuracy,
        feed_dict={features: test_features, labels: test_labels})

print('Test Accuracy: {}'.format(test_accuracy))
# Out:
# Extracting /datasets/ud730/mnist\train-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\train-labels-idx1-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-images-idx3-ubyte.gz
# Extracting /datasets/ud730/mnist\t10k-labels-idx1-ubyte.gz
# Epoch: 0    - Cost: 1.5      Valid Accuracy: 0.706
# Epoch: 1    - Cost: 0.798    Valid Accuracy: 0.785
# Epoch: 2    - Cost: 0.597    Valid Accuracy: 0.821
# Epoch: 3    - Cost: 0.509    Valid Accuracy: 0.838
# Epoch: 4    - Cost: 0.466    Valid Accuracy: 0.849
# Epoch: 5    - Cost: 0.442    Valid Accuracy: 0.854
# Epoch: 6    - Cost: 0.425    Valid Accuracy: 0.859
# Epoch: 7    - Cost: 0.412    Valid Accuracy: 0.864
# Epoch: 8    - Cost: 0.402    Valid Accuracy: 0.867
# Epoch: 9    - Cost: 0.393    Valid Accuracy: 0.872
# Epoch: 10   - Cost: 0.386    Valid Accuracy: 0.874
# Epoch: 11   - Cost: 0.379    Valid Accuracy: 0.876
# Epoch: 12   - Cost: 0.372    Valid Accuracy: 0.878
# Epoch: 13   - Cost: 0.366    Valid Accuracy: 0.88
# Epoch: 14   - Cost: 0.361    Valid Accuracy: 0.884
# Epoch: 15   - Cost: 0.356    Valid Accuracy: 0.885
# Epoch: 16   - Cost: 0.352    Valid Accuracy: 0.885
# Epoch: 17   - Cost: 0.347    Valid Accuracy: 0.886
# Epoch: 18   - Cost: 0.343    Valid Accuracy: 0.888
# Epoch: 19   - Cost: 0.339    Valid Accuracy: 0.889
# Epoch: 20   - Cost: 0.336    Valid Accuracy: 0.889
# Epoch: 21   - Cost: 0.332    Valid Accuracy: 0.889
# Epoch: 22   - Cost: 0.329    Valid Accuracy: 0.89
# Epoch: 23   - Cost: 0.326    Valid Accuracy: 0.89
# Epoch: 24   - Cost: 0.323    Valid Accuracy: 0.891
# Epoch: 25   - Cost: 0.32     Valid Accuracy: 0.892
# Epoch: 26   - Cost: 0.317    Valid Accuracy: 0.892
# Epoch: 27   - Cost: 0.315    Valid Accuracy: 0.894
# Epoch: 28   - Cost: 0.312    Valid Accuracy: 0.895
# Epoch: 29   - Cost: 0.31     Valid Accuracy: 0.897
# Epoch: 30   - Cost: 0.307    Valid Accuracy: 0.898
# Epoch: 31   - Cost: 0.305    Valid Accuracy: 0.899
# Epoch: 32   - Cost: 0.303    Valid Accuracy: 0.9
# Epoch: 33   - Cost: 0.301    Valid Accuracy: 0.901
# Epoch: 34   - Cost: 0.299    Valid Accuracy: 0.902
# Epoch: 35   - Cost: 0.297    Valid Accuracy: 0.903
# Epoch: 36   - Cost: 0.295    Valid Accuracy: 0.903
# Epoch: 37   - Cost: 0.293    Valid Accuracy: 0.904
# Epoch: 38   - Cost: 0.292    Valid Accuracy: 0.905
# Epoch: 39   - Cost: 0.29     Valid Accuracy: 0.905
# Epoch: 40   - Cost: 0.289    Valid Accuracy: 0.906
# Epoch: 41   - Cost: 0.287    Valid Accuracy: 0.906
# Epoch: 42   - Cost: 0.286    Valid Accuracy: 0.906
# Epoch: 43   - Cost: 0.284    Valid Accuracy: 0.907
# Epoch: 44   - Cost: 0.283    Valid Accuracy: 0.908
# Epoch: 45   - Cost: 0.282    Valid Accuracy: 0.908
# Epoch: 46   - Cost: 0.281    Valid Accuracy: 0.908
# Epoch: 47   - Cost: 0.28     Valid Accuracy: 0.909
# Epoch: 48   - Cost: 0.279    Valid Accuracy: 0.91
# Epoch: 49   - Cost: 0.277    Valid Accuracy: 0.911
# Epoch: 50   - Cost: 0.276    Valid Accuracy: 0.911
# Epoch: 51   - Cost: 0.276    Valid Accuracy: 0.911
# Epoch: 52   - Cost: 0.275    Valid Accuracy: 0.911
# Epoch: 53   - Cost: 0.274    Valid Accuracy: 0.912
# Epoch: 54   - Cost: 0.273    Valid Accuracy: 0.913
# Epoch: 55   - Cost: 0.272    Valid Accuracy: 0.913
# Epoch: 56   - Cost: 0.271    Valid Accuracy: 0.914
# Epoch: 57   - Cost: 0.27     Valid Accuracy: 0.914
# Epoch: 58   - Cost: 0.27     Valid Accuracy: 0.914
# Epoch: 59   - Cost: 0.269    Valid Accuracy: 0.915
# Epoch: 60   - Cost: 0.268    Valid Accuracy: 0.915
# Epoch: 61   - Cost: 0.268    Valid Accuracy: 0.915
# Epoch: 62   - Cost: 0.267    Valid Accuracy: 0.915
# Epoch: 63   - Cost: 0.266    Valid Accuracy: 0.915
# Epoch: 64   - Cost: 0.266    Valid Accuracy: 0.915
# Epoch: 65   - Cost: 0.265    Valid Accuracy: 0.915
# Epoch: 66   - Cost: 0.264    Valid Accuracy: 0.915
# Epoch: 67   - Cost: 0.264    Valid Accuracy: 0.915
# Epoch: 68   - Cost: 0.263    Valid Accuracy: 0.915
# Epoch: 69   - Cost: 0.263    Valid Accuracy: 0.916
# Epoch: 70   - Cost: 0.262    Valid Accuracy: 0.916
# Epoch: 71   - Cost: 0.262    Valid Accuracy: 0.916
# Epoch: 72   - Cost: 0.261    Valid Accuracy: 0.917
# Epoch: 73   - Cost: 0.261    Valid Accuracy: 0.917
# Epoch: 74   - Cost: 0.26     Valid Accuracy: 0.917
# Epoch: 75   - Cost: 0.26     Valid Accuracy: 0.917
# Epoch: 76   - Cost: 0.259    Valid Accuracy: 0.917
# Epoch: 77   - Cost: 0.259    Valid Accuracy: 0.917
# Epoch: 78   - Cost: 0.259    Valid Accuracy: 0.918
# Epoch: 79   - Cost: 0.258    Valid Accuracy: 0.918
# Epoch: 80   - Cost: 0.258    Valid Accuracy: 0.918
# Epoch: 81   - Cost: 0.257    Valid Accuracy: 0.919
# Epoch: 82   - Cost: 0.257    Valid Accuracy: 0.919
# Epoch: 83   - Cost: 0.256    Valid Accuracy: 0.919
# Epoch: 84   - Cost: 0.256    Valid Accuracy: 0.919
# Epoch: 85   - Cost: 0.256    Valid Accuracy: 0.919
# Epoch: 86   - Cost: 0.255    Valid Accuracy: 0.919
# Epoch: 87   - Cost: 0.255    Valid Accuracy: 0.919
# Epoch: 88   - Cost: 0.255    Valid Accuracy: 0.919
# Epoch: 89   - Cost: 0.254    Valid Accuracy: 0.919
# Epoch: 90   - Cost: 0.254    Valid Accuracy: 0.919
# Epoch: 91   - Cost: 0.254    Valid Accuracy: 0.919
# Epoch: 92   - Cost: 0.253    Valid Accuracy: 0.919
# Epoch: 93   - Cost: 0.253    Valid Accuracy: 0.92
# Epoch: 94   - Cost: 0.253    Valid Accuracy: 0.919
# Epoch: 95   - Cost: 0.252    Valid Accuracy: 0.92
# Epoch: 96   - Cost: 0.252    Valid Accuracy: 0.92
# Epoch: 97   - Cost: 0.252    Valid Accuracy: 0.92
# Epoch: 98   - Cost: 0.251    Valid Accuracy: 0.92
# Epoch: 99   - Cost: 0.251    Valid Accuracy: 0.92
# Epoch: 100  - Cost: 0.251    Valid Accuracy: 0.92
# Epoch: 101  - Cost: 0.25     Valid Accuracy: 0.921
# Epoch: 102  - Cost: 0.25     Valid Accuracy: 0.921
# Epoch: 103  - Cost: 0.25     Valid Accuracy: 0.921
# Epoch: 104  - Cost: 0.249    Valid Accuracy: 0.921
# Epoch: 105  - Cost: 0.249    Valid Accuracy: 0.921
# Epoch: 106  - Cost: 0.249    Valid Accuracy: 0.921
# Epoch: 107  - Cost: 0.249    Valid Accuracy: 0.921
# Epoch: 108  - Cost: 0.248    Valid Accuracy: 0.921
# Epoch: 109  - Cost: 0.248    Valid Accuracy: 0.922
# Epoch: 110  - Cost: 0.248    Valid Accuracy: 0.922
# Epoch: 111  - Cost: 0.247    Valid Accuracy: 0.923
# Epoch: 112  - Cost: 0.247    Valid Accuracy: 0.923
# Epoch: 113  - Cost: 0.247    Valid Accuracy: 0.923
# Epoch: 114  - Cost: 0.247    Valid Accuracy: 0.923
# Epoch: 115  - Cost: 0.246    Valid Accuracy: 0.923
# Epoch: 116  - Cost: 0.246    Valid Accuracy: 0.923
# Epoch: 117  - Cost: 0.246    Valid Accuracy: 0.923
# Epoch: 118  - Cost: 0.246    Valid Accuracy: 0.923
# Epoch: 119  - Cost: 0.245    Valid Accuracy: 0.923
# Epoch: 120  - Cost: 0.245    Valid Accuracy: 0.923
# Epoch: 121  - Cost: 0.245    Valid Accuracy: 0.923
# Epoch: 122  - Cost: 0.245    Valid Accuracy: 0.923
# Epoch: 123  - Cost: 0.244    Valid Accuracy: 0.923
# Epoch: 124  - Cost: 0.244    Valid Accuracy: 0.923
# Epoch: 125  - Cost: 0.244    Valid Accuracy: 0.923
# Epoch: 126  - Cost: 0.244    Valid Accuracy: 0.923
# Epoch: 127  - Cost: 0.243    Valid Accuracy: 0.923
# Epoch: 128  - Cost: 0.243    Valid Accuracy: 0.923
# Epoch: 129  - Cost: 0.243    Valid Accuracy: 0.923
# Epoch: 130  - Cost: 0.243    Valid Accuracy: 0.923
# Epoch: 131  - Cost: 0.242    Valid Accuracy: 0.923
# Epoch: 132  - Cost: 0.242    Valid Accuracy: 0.923
# Epoch: 133  - Cost: 0.242    Valid Accuracy: 0.923
# Epoch: 134  - Cost: 0.242    Valid Accuracy: 0.923
# Epoch: 135  - Cost: 0.242    Valid Accuracy: 0.924
# Epoch: 136  - Cost: 0.241    Valid Accuracy: 0.924
# Epoch: 137  - Cost: 0.241    Valid Accuracy: 0.924
# Epoch: 138  - Cost: 0.241    Valid Accuracy: 0.924
# Epoch: 139  - Cost: 0.241    Valid Accuracy: 0.924
# Epoch: 140  - Cost: 0.24     Valid Accuracy: 0.925
# Epoch: 141  - Cost: 0.24     Valid Accuracy: 0.925
# Epoch: 142  - Cost: 0.24     Valid Accuracy: 0.925
# Epoch: 143  - Cost: 0.24     Valid Accuracy: 0.925
# Epoch: 144  - Cost: 0.24     Valid Accuracy: 0.925
# Epoch: 145  - Cost: 0.239    Valid Accuracy: 0.925
# Epoch: 146  - Cost: 0.239    Valid Accuracy: 0.925
# Epoch: 147  - Cost: 0.239    Valid Accuracy: 0.925
# Epoch: 148  - Cost: 0.239    Valid Accuracy: 0.925
# Epoch: 149  - Cost: 0.238    Valid Accuracy: 0.925
# Epoch: 150  - Cost: 0.238    Valid Accuracy: 0.925
# Epoch: 151  - Cost: 0.238    Valid Accuracy: 0.925
# Epoch: 152  - Cost: 0.238    Valid Accuracy: 0.925
# Epoch: 153  - Cost: 0.238    Valid Accuracy: 0.925
# Epoch: 154  - Cost: 0.237    Valid Accuracy: 0.925
# Epoch: 155  - Cost: 0.237    Valid Accuracy: 0.925
# Epoch: 156  - Cost: 0.237    Valid Accuracy: 0.925
# Epoch: 157  - Cost: 0.237    Valid Accuracy: 0.925
# Epoch: 158  - Cost: 0.236    Valid Accuracy: 0.925
# Epoch: 159  - Cost: 0.236    Valid Accuracy: 0.925
# Epoch: 160  - Cost: 0.236    Valid Accuracy: 0.925
# Epoch: 161  - Cost: 0.236    Valid Accuracy: 0.925
# Epoch: 162  - Cost: 0.236    Valid Accuracy: 0.924
# Epoch: 163  - Cost: 0.235    Valid Accuracy: 0.924
# Epoch: 164  - Cost: 0.235    Valid Accuracy: 0.924
# Epoch: 165  - Cost: 0.235    Valid Accuracy: 0.924
# Epoch: 166  - Cost: 0.235    Valid Accuracy: 0.924
# Epoch: 167  - Cost: 0.235    Valid Accuracy: 0.924
# Epoch: 168  - Cost: 0.234    Valid Accuracy: 0.924
# Epoch: 169  - Cost: 0.234    Valid Accuracy: 0.924
# Epoch: 170  - Cost: 0.234    Valid Accuracy: 0.925
# Epoch: 171  - Cost: 0.234    Valid Accuracy: 0.925
# Epoch: 172  - Cost: 0.234    Valid Accuracy: 0.925
# Epoch: 173  - Cost: 0.233    Valid Accuracy: 0.925
# Epoch: 174  - Cost: 0.233    Valid Accuracy: 0.925
# Epoch: 175  - Cost: 0.233    Valid Accuracy: 0.925
# Epoch: 176  - Cost: 0.233    Valid Accuracy: 0.925
# Epoch: 177  - Cost: 0.232    Valid Accuracy: 0.925
# Epoch: 178  - Cost: 0.232    Valid Accuracy: 0.925
# Epoch: 179  - Cost: 0.232    Valid Accuracy: 0.925
# Epoch: 180  - Cost: 0.232    Valid Accuracy: 0.925
# Epoch: 181  - Cost: 0.232    Valid Accuracy: 0.925
# Epoch: 182  - Cost: 0.231    Valid Accuracy: 0.925
# Epoch: 183  - Cost: 0.231    Valid Accuracy: 0.925
# Epoch: 184  - Cost: 0.231    Valid Accuracy: 0.925
# Epoch: 185  - Cost: 0.231    Valid Accuracy: 0.925
# Epoch: 186  - Cost: 0.231    Valid Accuracy: 0.925
# Epoch: 187  - Cost: 0.23     Valid Accuracy: 0.925
# Epoch: 188  - Cost: 0.23     Valid Accuracy: 0.925
# Epoch: 189  - Cost: 0.23     Valid Accuracy: 0.925
# Epoch: 190  - Cost: 0.23     Valid Accuracy: 0.925
# Epoch: 191  - Cost: 0.23     Valid Accuracy: 0.925
# Epoch: 192  - Cost: 0.229    Valid Accuracy: 0.925
# Epoch: 193  - Cost: 0.229    Valid Accuracy: 0.925
# Epoch: 194  - Cost: 0.229    Valid Accuracy: 0.925
# Epoch: 195  - Cost: 0.229    Valid Accuracy: 0.925
# Epoch: 196  - Cost: 0.229    Valid Accuracy: 0.925
# Epoch: 197  - Cost: 0.228    Valid Accuracy: 0.925
# Epoch: 198  - Cost: 0.228    Valid Accuracy: 0.925
# Epoch: 199  - Cost: 0.228    Valid Accuracy: 0.925
# Test Accuracy: 0.9199000000953674
